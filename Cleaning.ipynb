# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Primero. Traemos el csv (grabado en INPUT en este caso) y lo abrimos con pd

# %%
df = pd.read_csv('INPUT/attacks.csv', encoding='latin-1')

# %%
## comprobamos

# %%
df.head(40)
# Out:
#      Case Number                  Date    Year          Type        Country  \
# 0     2018.06.25           25-Jun-2018  2018.0       Boating            USA
# 1     2018.06.18           18-Jun-2018  2018.0    Unprovoked            USA
# 2     2018.06.09           09-Jun-2018  2018.0       Invalid            USA
# 3     2018.06.08           08-Jun-2018  2018.0    Unprovoked      AUSTRALIA
# 4     2018.06.04           04-Jun-2018  2018.0      Provoked         MEXICO
# 5   2018.06.03.b           03-Jun-2018  2018.0    Unprovoked      AUSTRALIA
# 6   2018.06.03.a           03-Jun-2018  2018.0    Unprovoked         BRAZIL
# 7     2018.05.27           27-May-2018  2018.0    Unprovoked            USA
# 8   2018.05.26.b           26-May-2018  2018.0    Unprovoked            USA
# 9   2018.05.26.a           26-May-2018  2018.0    Unprovoked            USA
# 10    2018.05.24           24-May-2018  2018.0      Provoked      AUSTRALIA
# ...

# %%
## lo primero es saber cosas basicas del df

# %%
#Rows and columns
df.shape
# Out:
# (25723, 24)

# %%
# Codigo que directamente quita los duplicados

df = df.drop_duplicates()

# %%
df.shape
# Out:
# (6312, 24)

# %%
#OJO REPASAR Esta formula se puede utilizar pero la tenemos abajo mucho mas molona 
for col, numnulls in df.isnull().sum().items():
    if numnulls > 0:
        print(f"{col} {numnulls}")
# Out:
# Case Number 2
# Date 10
# Year 12
# Type 14
# Country 60
# Area 465
# Location 550
# Activity 554
# Name 220
# Sex  575
# Age 2841
# Injury 38
# Fatal (Y/N) 549
# Time 3364
# Species  2848
# Investigator or Source 27
# pdf 10
# href formula 11
# href 10
# Case Number.1 10
# Case Number.2 10
# original order 3
# Unnamed: 22 6311
# Unnamed: 23 6310

# %%
###buscar la manera de imprimir los valores de unnamed 22 y unnamed 23 solo si no son nulos
#esta hecho pero de una manera poco apropiada

# %%
las dos ultimas columnas tienen valores nulos casi todos. veamos que valores tienen esos 2 o 3 filas con valor

# %%
filtered_df = df[df['Unnamed: 22'].notnull()]

# %%
filtered_df
# Out:
#      Case Number         Date    Year        Type Country    Area  \
# 1478  2006.05.27  27-May-2006  2006.0  Unprovoked     USA  Hawaii
#
#                 Location Activity          Name Sex   ... Species   \
# 1478  North Shore, O'ahu  Surfing  Bret Desmond    M  ...      NaN
#
#      Investigator or Source                     pdf  \
# 1478             R. Collier  2006.05.27-Desmond.pdf
#
#                                            href formula  \
# 1478  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 1478  http://sharkattackfile.net/spreadsheets/pdf_di...    2006.05.27
#
#      Case Number.2 original order   Unnamed: 22 Unnamed: 23
# 1478    2006.05.27         4825.0  stopped here         NaN
#
# [1 rows x 24 columns]

# %%
filtered_df = df[df['Unnamed: 23'].notnull()]

# %%
filtered_df
# Out:
#        Case Number                  Date    Year        Type  \
# 4415    1952.03.30           30-Mar-1952  1952.0  Unprovoked
# 5840  1878.09.14.R  Reported 14-Sep-1878  1878.0    Provoked
#
#                    Country         Area                    Location  \
# 4415  NETHERLANDS ANTILLES      Curacao                         NaN
# 5840                   USA  Connecticut  Branford, New Haven County
#
#                                              Activity              Name Sex   \
# 4415  Went to aid of child being menaced by the shark       A.J. Eggink    M
# 5840                                          Fishing  Captain Pattison    M
#
#       ...                                           Species   \
# 4415  ...  Bull shark, 2.7 m [9'] was captured & dragged ...
# 5840  ...                                                NaN
#
#                                  Investigator or Source  \
# 4415  J. Randall, p.352 in Sharks & Survival; H.D. B...
# ...

# %%
## Claramente podemos eliminas esas columnas

# %%
df = df.drop('Unnamed: 23', 1)

# %%
df = df.drop('Unnamed: 22', 1)
# df = df.drop(columns=["pdf", "Investigator or Source","href formula"])

# %%
df.head(3)
# Out:
#   Case Number         Date    Year        Type Country        Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating     USA  California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked     USA     Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid     USA      Hawaii
#
#                          Location  Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County  Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County  Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu   Surfing      John Denges    M  ...
#
#   Fatal (Y/N)           Time     Species           Investigator or Source  \
# 0           N          18h00  White shark                R. Collier, GSAF
# 1           N  14h00  -15h00          NaN  K.McMurray, TrackingSharks.com
# 2           N          07h45          NaN  K.McMurray, TrackingSharks.com
#
#                       pdf                                       href formula  \
# ...

# %%
# df = df.drop(columns=["losquesea", "loquesea2"]) tbn serviria.

# %%
df.tail(20)
# Out:
#       Case Number         Date  Year        Type             Country  \
# 6292      ND.0010   Circa 1862   0.0  Unprovoked                 USA
# 6293      ND.0009  Before 1906   0.0  Unprovoked           AUSTRALIA
# 6294      ND.0008  Before 1906   0.0  Unprovoked           AUSTRALIA
# 6295      ND.0007  Before 1906   0.0  Unprovoked           AUSTRALIA
# 6296      ND.0006  Before 1906   0.0  Unprovoked           AUSTRALIA
# 6297      ND.0005  Before 1903   0.0  Unprovoked           AUSTRALIA
# 6298      ND.0004  Before 1903   0.0  Unprovoked           AUSTRALIA
# 6299      ND.0003    1900-1905   0.0  Unprovoked                 USA
# 6300      ND.0002    1883-1889   0.0  Unprovoked              PANAMA
# 6301      ND.0001    1845-1853   0.0  Unprovoked  CEYLON (SRI LANKA)
# 6302            0          NaN   NaN         NaN                 NaN
# 6303            0          NaN   NaN         NaN                 NaN
# 6304            0          NaN   NaN         NaN                 NaN
# ...

# %%
# los ultimos 10 valores a partir de 6301 son invalidos. Los eliminamos. 
df.drop(df.tail(10).index,inplace=True)

# %%
df.isnull().sum().sort_values(ascending=False).head(20)
#esta es la formula que tenemos arriba pero mas molona
# Out:
# Time                      3354
# Species                   2838
# Age                       2831
# Sex                        565
# Activity                   544
# Location                   540
# Fatal (Y/N)                539
# Area                       455
# Name                       210
# Country                     50
# Injury                      28
# Investigator or Source      17
# Type                         4
# Year                         2
# Case Number                  1
# href formula                 1
# Case Number.2                0
# pdf                          0
# href                         0
# Case Number.1                0
# dtype: int64

# %%
df.shape
# Out:
# (6302, 22)

# %%
#He hecho una primera limpieza de la tabla. De (25723, 24) lo he pasado a (6312, 22) sin eliminar ni un solo dato.
#Lo llamo dfraw y comienzo a trabajar con este nuevo df para conseguir otra tabla que tenga los datos que puedan 
#ser interesantes para nuestra tabla.

# %%
dfraw = df

# %%
# voy a ir columna por columna viendo si el dato merece la pena guardarlo, desecharlo o cambiar algo.

# %%
#1.- case number y date parecen iguales.

# %%
dfraw.head(10)
# Out:
#           Date        Type    Country             Area  \
# 0  25-Jun-2018     Boating        USA       California
# 1  18-Jun-2018  Unprovoked        USA          Georgia
# 2  09-Jun-2018     Invalid        USA           Hawaii
# 3  08-Jun-2018  Unprovoked  AUSTRALIA  New South Wales
# 4  04-Jun-2018    Provoked     MEXICO           Colima
# 5  03-Jun-2018  Unprovoked  AUSTRALIA  New South Wales
# 6  03-Jun-2018  Unprovoked     BRAZIL       Pernambuco
# 7  27-May-2018  Unprovoked        USA          Florida
# 8  26-May-2018  Unprovoked        USA          Florida
# 9  26-May-2018  Unprovoked        USA          Florida
#
#                                             Location      Activity  \
# 0                        Oceanside, San Diego County      Paddling
# 1                     St. Simon Island, Glynn County      Standing
# 2                                       Habush, Oahu       Surfing
# 3                                 Arrawarra Headland       Surfing
# ...

# %%
dfraw.tail(10)
# Out:
#                      Date        Type       Country                   Area  \
# 819           06-Feb-2012  Unprovoked     AUSTRALIA             Queensland
# 820           27-Jan-2012  Unprovoked           USA                 Hawaii
# 821           19-Jan-2012  Unprovoked     AUSTRALIA      Western Australia
# 822  Reported 22-Jan-2012  Unprovoked       BAHAMAS                    NaN
# 823           18-Jan-2012    Provoked        TAIWAN               Taitung
# 824           18-Jan-2012  Unprovoked     AUSTRALIA        New South Wales
# 825           15-Jan-2012  Unprovoked  SOUTH AFRICA  Eastern Cape Province
# 826           13-Jan-2012  Unprovoked           USA                 Oregon
# 827           03-Jan-2012  Unprovoked     AUSTRALIA        New South Wales
# 828           02-Jan-2012  Unprovoked     AUSTRALIA             Queensland
#
#                          Location                      Activity  \
# 819                      Wurtulla                       Surfing
# ...

# %%
# En cualquier caso solo quiero los datos a partir de 2011. Eliminamos los anteriores
dfraw = dfraw[dfraw.Year > 2010.0]
dfraw.shape
# Out:
# (956, 22)

# %%
# elimino case y year y me quedo solo con date
dfraw = dfraw.drop(columns = ['Case Number','Year'])

# %%
# Observo ademas  que hay varias columnas que no me ofrecen ningun interes. Las elimino
dfraw = dfraw.drop(columns =['Investigator or Source', 'pdf' ,'href formula' ,'href','Case Number.1' ,'Case Number.2'])

# %%
dfraw.head()
# Out:
#           Date        Type    Country             Area  \
# 0  25-Jun-2018     Boating        USA       California
# 1  18-Jun-2018  Unprovoked        USA          Georgia
# 2  09-Jun-2018     Invalid        USA           Hawaii
# 3  08-Jun-2018  Unprovoked  AUSTRALIA  New South Wales
# 4  04-Jun-2018    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# ...

# %%
dfraw.shape
# Out:
# (956, 14)

# %%
#veamos cuantos paises estan en la tabla
dfraw.Country.unique()
# Out:
# array(['USA', 'AUSTRALIA', 'MEXICO', 'BRAZIL', 'ENGLAND', 'SOUTH AFRICA',
#        'THAILAND', 'COSTA RICA', 'MALDIVES', 'BAHAMAS', 'NEW CALEDONIA',
#        'ECUADOR', 'MALAYSIA', 'LIBYA', nan, 'CUBA', 'MAURITIUS',
#        'NEW ZEALAND', 'SPAIN', 'SAMOA', 'SOLOMON ISLANDS', 'JAPAN',
#        'EGYPT', 'ST HELENA, British overseas territory', 'COMOROS',
#        'REUNION', 'FRENCH POLYNESIA', 'UNITED KINGDOM',
#        'UNITED ARAB EMIRATES', 'PHILIPPINES', 'INDONESIA', 'CHINA',
#        'COLUMBIA', 'CAPE VERDE', 'Fiji', 'DOMINICAN REPUBLIC',
#        'CAYMAN ISLANDS', 'ARUBA', 'MOZAMBIQUE', 'FIJI', 'PUERTO RICO',
#        'ITALY', 'ATLANTIC OCEAN', 'GREECE', 'ST. MARTIN', 'FRANCE',
#        'PAPUA NEW GUINEA', 'TRINIDAD & TOBAGO', 'KIRIBATI', 'ISRAEL',
#        'DIEGO GARCIA', 'TAIWAN', 'JAMAICA', 'PALESTINIAN TERRITORIES',
#        'GUAM', 'SEYCHELLES', 'BELIZE', 'NIGERIA', 'TONGA', 'SCOTLAND',
#        'CANADA', 'CROATIA', 'SAUDI ARABIA', 'CHILE', 'ANTIGUA', 'KENYA',
# ...

# %%
#veamos casos por paises

# %%
dfraw[dfraw.Country.isnull()]
# Out:
#                      Date        Type Country Area Location      Activity  \
# 62   Reported 13-Nov-2017  Unprovoked     NaN  NaN      NaN       Surfing
# 525              Aug-2014     Invalid     NaN  NaN      NaN  Sea disaster
#
#                Name Sex   Age                                          Injury  \
# 62    Timur Yunusov    M   24                         Puncture wounds to feet
# 525  Cuban refugees    M  NaN  Shark involvement prior to death not confirmed
#
#     Fatal (Y/N) Time                         Species   original order
# 62            N  NaN                              NaN          6241.0
# 525         NaN  NaN  Shark involvement not confirmed          5778.0

# %%
primero limpiar la tabla exportar table limpia y volver a hacer limpieza de datos y cambio de nombres solo para lo que buscamos.
